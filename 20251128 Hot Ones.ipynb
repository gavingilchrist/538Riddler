# %%
ways_to_make = lambda x, y=1: [set()] if x==0 else [] if x<0 or y>10 else [{i}|j for i in range(y, 11) for j in ways_to_make(x-i, i+1)]
get_combos = lambda x, y=1: [set()] if x==0 else [] if y>10 else [{i}|j for i in range(y, 11) for j in get_combos(x-1, i+1)]
len(z:=[i for i in get_combos(4) if all([any([k.issubset(i) for k in ways_to_make(j)]) for j in range(1, 11)])]), z
# Out:
# (8,
#  [{1, 2, 3, 4},
#   {1, 2, 3, 5},
#   {1, 2, 3, 6},
#   {1, 2, 3, 7},
#   {1, 2, 4, 5},
#   {1, 2, 4, 6},
#   {1, 2, 4, 7},
#   {1, 2, 4, 8}])
